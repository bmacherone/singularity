# %%
# load the rhh, schema, reverse schema
import pickle

afile = open(r'rhh.pkl', 'rb')
rhh = pickle.load(afile)
afile.close()

afile = open(r'rhh_si.pkl', 'rb')
rhh_si = pickle.load(afile)
afile.close()

afile = open(r'rhh_rsi.pkl', 'rb')
rhh_rsi = pickle.load(afile)
afile.close()

print(len(rhh))
print("")
print(rhh_si)
print("")
print(rhh_rsi)
# Out:
# 11181
#
# ...
